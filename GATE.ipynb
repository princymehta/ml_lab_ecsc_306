# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



multiply1=tf.add(tf.matmul(x,weights),bias)
z=tf.nn.sigmoid(multiply1)


cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[0],[0],[1]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(12001):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration= ",i,"cost= ",res)
    print ("Validating output for AND GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration=  0 cost=  0.991168
# iteration=  1000 cost=  0.501678
# iteration=  2000 cost=  0.385773
# iteration=  3000 cost=  0.316539
# iteration=  4000 cost=  0.270033
# iteration=  5000 cost=  0.236213
# iteration=  6000 cost=  0.210263
# iteration=  7000 cost=  0.189591
# iteration=  8000 cost=  0.172667
# iteration=  9000 cost=  0.158519
# iteration=  10000 cost=  0.146497
# iteration=  11000 cost=  0.136145
# iteration=  12000 cost=  0.127133
# Validating output for AND GATE
# [[ 0.00573718]
#  [ 0.13494939]
#  [ 0.13487306]
#  [ 0.80823809]]

# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



multiply1=tf.add(tf.matmul(x,weights),bias)
z=tf.nn.sigmoid(multiply1)


cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[1],[1],[1]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(12001):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration= ",i,"cost= ",res)
    print ("Validating output for OR GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration=  0 cost=  0.579586
# iteration=  1000 cost=  0.414732
# iteration=  2000 cost=  0.312995
# iteration=  3000 cost=  0.248306
# iteration=  4000 cost=  0.204528
# iteration=  5000 cost=  0.173172
# iteration=  6000 cost=  0.149704
# iteration=  7000 cost=  0.131534
# iteration=  8000 cost=  0.117087
# iteration=  9000 cost=  0.10535
# iteration=  10000 cost=  0.0956434
# iteration=  11000 cost=  0.0874954
# iteration=  12000 cost=  0.080567
# Validating output for OR GATE
# [[ 0.16886902]
#  [ 0.9339245 ]
#  [ 0.93434912]
#  [ 0.99899095]]

# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

#weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
#bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



#multiply1=tf.add(tf.matmul(x,weights),bias)
#z=tf.nn.sigmoid(multiply1)


Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name="Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name="Theta2")
Bias1 = tf.Variable(tf.zeros([2]), name="Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name="Bias2")
A2 = tf.sigmoid(tf.matmul(x, Theta1) + Bias1)
z = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)
    
cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[1],[1],[0]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(100000):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration = ",i,"cost= ",res)
    print ("Validating output for XOR GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration =  0 cost=  0.697589
# iteration =  1000 cost=  0.693269
# iteration =  2000 cost=  0.693247
# iteration =  3000 cost=  0.693227
# iteration =  4000 cost=  0.693208
# iteration =  5000 cost=  0.693189
# iteration =  6000 cost=  0.69317
# iteration =  7000 cost=  0.693151
# iteration =  8000 cost=  0.693131
# iteration =  9000 cost=  0.69311
# iteration =  10000 cost=  0.693089
# iteration =  11000 cost=  0.693066
# iteration =  12000 cost=  0.693041
# iteration =  13000 cost=  0.693014
# iteration =  14000 cost=  0.692984
# iteration =  15000 cost=  0.69295
# iteration =  16000 cost=  0.692912
# iteration =  17000 cost=  0.692869
# iteration =  18000 cost=  0.692819
# iteration =  19000 cost=  0.692762
# iteration =  20000 cost=  0.692694
# iteration =  21000 cost=  0.692614
# iteration =  22000 cost=  0.692518
# iteration =  23000 cost=  0.692403
# iteration =  24000 cost=  0.692263
# iteration =  25000 cost=  0.692092
# iteration =  26000 cost=  0.69188
# iteration =  27000 cost=  0.691617
# iteration =  28000 cost=  0.691287
# iteration =  29000 cost=  0.690872
# iteration =  30000 cost=  0.690346
# iteration =  31000 cost=  0.689677
# iteration =  32000 cost=  0.688824
# iteration =  33000 cost=  0.687738
# iteration =  34000 cost=  0.686357
# iteration =  35000 cost=  0.684612
# iteration =  36000 cost=  0.682419
# iteration =  37000 cost=  0.679688
# iteration =  38000 cost=  0.676318
# iteration =  39000 cost=  0.672197
# iteration =  40000 cost=  0.667203
# iteration =  41000 cost=  0.661209
# iteration =  42000 cost=  0.654093
# iteration =  43000 cost=  0.645758
# iteration =  44000 cost=  0.636169
# iteration =  45000 cost=  0.625375
# iteration =  46000 cost=  0.613526
# iteration =  47000 cost=  0.600848
# iteration =  48000 cost=  0.587604
# iteration =  49000 cost=  0.574027
# iteration =  50000 cost=  0.560263
# iteration =  51000 cost=  0.54633
# iteration =  52000 cost=  0.532094
# iteration =  53000 cost=  0.517261
# iteration =  54000 cost=  0.501387
# iteration =  55000 cost=  0.483893
# iteration =  56000 cost=  0.464137
# iteration =  57000 cost=  0.441527
# iteration =  58000 cost=  0.415709
# iteration =  59000 cost=  0.386773
# iteration =  60000 cost=  0.355385
# iteration =  61000 cost=  0.322746
# iteration =  62000 cost=  0.290326
# iteration =  63000 cost=  0.259506
# iteration =  64000 cost=  0.231267
# iteration =  65000 cost=  0.206109
# iteration =  66000 cost=  0.18412
# iteration =  67000 cost=  0.16512
# iteration =  68000 cost=  0.148792
# iteration =  69000 cost=  0.134779
# iteration =  70000 cost=  0.122731
# iteration =  71000 cost=  0.112338
# iteration =  72000 cost=  0.103331
# iteration =  73000 cost=  0.0954853
# iteration =  74000 cost=  0.0886137
# iteration =  75000 cost=  0.0825631
# iteration =  76000 cost=  0.077207
# iteration =  77000 cost=  0.0724415
# iteration =  78000 cost=  0.0681808
# iteration =  79000 cost=  0.0643539
# iteration =  80000 cost=  0.0609014
# iteration =  81000 cost=  0.057774
# iteration =  82000 cost=  0.0549305
# iteration =  83000 cost=  0.0523357
# iteration =  84000 cost=  0.0499596
# iteration =  85000 cost=  0.0477769
# iteration =  86000 cost=  0.0457656
# iteration =  87000 cost=  0.043908
# iteration =  88000 cost=  0.0421869
# iteration =  89000 cost=  0.0405886
# iteration =  90000 cost=  0.0391005
# iteration =  91000 cost=  0.0377127
# iteration =  92000 cost=  0.0364147
# iteration =  93000 cost=  0.0351995
# iteration =  94000 cost=  0.0340591
# iteration =  95000 cost=  0.0329865
# iteration =  96000 cost=  0.0319769
# iteration =  97000 cost=  0.0310247
# iteration =  98000 cost=  0.0301247
# iteration =  99000 cost=  0.0292737
# Validating output for XOR GATE
# [[ 0.031181  ]
#  [ 0.97418302]
#  [ 0.9741993 ]
#  [ 0.02945546]]

# %%
import tensorflow as tf
x_ = tf.placeholder(tf.float32, shape=[4,2], name="x-input")
y_ = tf.placeholder(tf.float32, shape=[4,1], name="y-input")
Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name="Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name="Theta2")
Bias1 = tf.Variable(tf.zeros([2]), name="Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name="Bias2")
A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)
Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)
cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
        ((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)
for i in range(100000):
        sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})

        
if i % 1000 == 0:
        print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
